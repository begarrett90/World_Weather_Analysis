# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of 2000 random (lat,long) combos
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
longs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
#Create list if coordinates
coordinates = list(lat_longs)

# %%
from citipy import citipy

# %%
#List to hold cities
cities = []
#Find nearest city from citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #if city is new add to cities list
    if city not in cities:
        cities.append(city)

#confirm length of city count
len(cities)
# Out:
# 752

# %%
#Import request library
import requests

#Import API key
from key import weather_api_key
#from config import weather_api_key

# %%
#URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
#url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# # Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_condition = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_condition,
                          "Date": city_date
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | san quintin
# Processing Record 2 of Set 1 | nantucket
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | camacha
# Processing Record 5 of Set 1 | chimbote
# Processing Record 6 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | lazaro cardenas
# Processing Record 10 of Set 1 | safford
# Processing Record 11 of Set 1 | bud
# Processing Record 12 of Set 1 | cuicatlan
# Processing Record 13 of Set 1 | naze
# Processing Record 14 of Set 1 | tual
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | aklavik
# Processing Record 17 of Set 1 | salalah
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | harper
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | paamiut
# Processing Record 23 of Set 1 | half moon bay
# Processing Record 24 of Set 1 | wasilla
# Processing Record 25 of Set 1 | baykit
# Processing Record 26 of Set 1 | braganca
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | olinda
# Processing Record 32 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | ullapool
# Processing Record 37 of Set 1 | bardiyah
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | sisimiut
# Processing Record 42 of Set 1 | homer
# Processing Record 43 of Set 1 | inhambane
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | uruzgan
# Processing Record 48 of Set 1 | lusambo
# Processing Record 49 of Set 1 | toledo
# Processing Record 50 of Set 1 | nelson bay
# Processing Record 1 of Set 2 | altay
# Processing Record 2 of Set 2 | bardsir
# Processing Record 3 of Set 2 | egvekinot
# Processing Record 4 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 2 | ishigaki
# Processing Record 6 of Set 2 | bambanglipuro
# Processing Record 7 of Set 2 | halifax
# Processing Record 8 of Set 2 | san pedro
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | davenda
# Processing Record 14 of Set 2 | alofi
# Processing Record 15 of Set 2 | nalut
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | vestmannaeyjar
# Processing Record 19 of Set 2 | shelburne
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | sidi bu zayd
# City not found. Skipping...
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | ilebo
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | olafsvik
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | isangel
# Processing Record 31 of Set 2 | high level
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | margate
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | belgrade
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | tenenkou
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | luanda
# Processing Record 43 of Set 2 | lagoa
# Processing Record 44 of Set 2 | bauru
# Processing Record 45 of Set 2 | luwuk
# Processing Record 46 of Set 2 | hervey bay
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | yurimaguas
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | poum
# Processing Record 4 of Set 3 | odesskoye
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | annau
# Processing Record 7 of Set 3 | ponta delgada
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | bonavista
# Processing Record 10 of Set 3 | arrecife
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | kapit
# Processing Record 13 of Set 3 | freeport
# Processing Record 14 of Set 3 | rio cuarto
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | tkvarcheli
# City not found. Skipping...
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | siva
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | tecoanapa
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | banjar
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | skjervoy
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | yinchuan
# Processing Record 37 of Set 3 | marsh harbour
# Processing Record 38 of Set 3 | bestobe
# Processing Record 39 of Set 3 | port hardy
# Processing Record 40 of Set 3 | palana
# Processing Record 41 of Set 3 | bartica
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | mastic beach
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | mount isa
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | southbridge
# Processing Record 48 of Set 3 | burns lake
# Processing Record 49 of Set 3 | marawi
# Processing Record 50 of Set 3 | jalu
# Processing Record 1 of Set 4 | omsukchan
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | santa rosa
# Processing Record 4 of Set 4 | te anau
# Processing Record 5 of Set 4 | vila do maio
# Processing Record 6 of Set 4 | vanimo
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | jamestown
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | praya
# Processing Record 12 of Set 4 | pisco
# Processing Record 13 of Set 4 | sanmenxia
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | saint-georges
# Processing Record 16 of Set 4 | marathopolis
# City not found. Skipping...
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | cape town
# Processing Record 19 of Set 4 | angoche
# Processing Record 20 of Set 4 | veraval
# Processing Record 21 of Set 4 | bac lieu
# Processing Record 22 of Set 4 | nemuro
# Processing Record 23 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | ipixuna
# Processing Record 27 of Set 4 | witu
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | benguela
# Processing Record 30 of Set 4 | ramgarh
# Processing Record 31 of Set 4 | wa
# City not found. Skipping...
# Processing Record 32 of Set 4 | putina
# Processing Record 33 of Set 4 | labrea
# Processing Record 34 of Set 4 | kitob
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | japura
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | taree
# Processing Record 41 of Set 4 | kokstad
# Processing Record 42 of Set 4 | kassala
# Processing Record 43 of Set 4 | hermanus
# Processing Record 44 of Set 4 | victoria point
# Processing Record 45 of Set 4 | flin flon
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | mikhaylovka
# Processing Record 48 of Set 4 | westport
# Processing Record 49 of Set 4 | fuquay-varina
# Processing Record 50 of Set 4 | taltal
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | coquimbo
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | beyneu
# Processing Record 5 of Set 5 | kaeo
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | khatanga
# Processing Record 9 of Set 5 | diebougou
# Processing Record 10 of Set 5 | ramsi
# Processing Record 11 of Set 5 | portsmouth
# Processing Record 12 of Set 5 | carinhanha
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | georgetown
# Processing Record 15 of Set 5 | itamaraca
# Processing Record 16 of Set 5 | yar-sale
# Processing Record 17 of Set 5 | novo aripuana
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | mahmudia
# Processing Record 20 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 21 of Set 5 | miles city
# Processing Record 22 of Set 5 | port hueneme
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | mouzouras
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | nanortalik
# Processing Record 27 of Set 5 | cabra
# Processing Record 28 of Set 5 | tasiilaq
# Processing Record 29 of Set 5 | nome
# Processing Record 30 of Set 5 | gouyave
# Processing Record 31 of Set 5 | bauchi
# Processing Record 32 of Set 5 | koboldo
# City not found. Skipping...
# Processing Record 33 of Set 5 | san juan
# Processing Record 34 of Set 5 | svobodnyy
# Processing Record 35 of Set 5 | hami
# Processing Record 36 of Set 5 | yulara
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | luderitz
# Processing Record 39 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 5 | taoudenni
# Processing Record 41 of Set 5 | sape
# Processing Record 42 of Set 5 | pontes e lacerda
# Processing Record 43 of Set 5 | ustye
# Processing Record 44 of Set 5 | safaqis
# City not found. Skipping...
# Processing Record 45 of Set 5 | whitehorse
# Processing Record 46 of Set 5 | siniscola
# Processing Record 47 of Set 5 | minab
# Processing Record 48 of Set 5 | dwarka
# Processing Record 49 of Set 5 | polunochnoye
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | kieta
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | vaitape
# Processing Record 4 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 6 | touros
# Processing Record 6 of Set 6 | makakilo city
# Processing Record 7 of Set 6 | san vicente
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | kenai
# Processing Record 12 of Set 6 | samana
# Processing Record 13 of Set 6 | visby
# Processing Record 14 of Set 6 | obo
# Processing Record 15 of Set 6 | svetlyy
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | sibolga
# Processing Record 18 of Set 6 | kochi
# Processing Record 19 of Set 6 | burnie
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | sangar
# Processing Record 22 of Set 6 | pangai
# Processing Record 23 of Set 6 | mecca
# Processing Record 24 of Set 6 | aranda de duero
# Processing Record 25 of Set 6 | sovetskiy
# Processing Record 26 of Set 6 | kawhia
# Processing Record 27 of Set 6 | yumen
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | xiaoweizhai
# Processing Record 30 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 6 | potsdam
# Processing Record 32 of Set 6 | flagstaff
# Processing Record 33 of Set 6 | nueva gerona
# Processing Record 34 of Set 6 | abatskoye
# Processing Record 35 of Set 6 | ndele
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | saint-augustin
# Processing Record 38 of Set 6 | antofagasta
# Processing Record 39 of Set 6 | sur
# Processing Record 40 of Set 6 | rurrenabaque
# Processing Record 41 of Set 6 | sulina
# Processing Record 42 of Set 6 | fandriana
# Processing Record 43 of Set 6 | andenes
# Processing Record 44 of Set 6 | cairns
# Processing Record 45 of Set 6 | leningradskiy
# Processing Record 46 of Set 6 | pangnirtung
# Processing Record 47 of Set 6 | tala
# Processing Record 48 of Set 6 | qeshm
# Processing Record 49 of Set 6 | waingapu
# Processing Record 50 of Set 6 | tonj
# Processing Record 1 of Set 7 | cherskiy
# Processing Record 2 of Set 7 | wielun
# Processing Record 3 of Set 7 | ulaangom
# Processing Record 4 of Set 7 | dovolnoye
# Processing Record 5 of Set 7 | dalaba
# Processing Record 6 of Set 7 | baley
# Processing Record 7 of Set 7 | nueva loja
# Processing Record 8 of Set 7 | zabrat
# Processing Record 9 of Set 7 | teguldet
# Processing Record 10 of Set 7 | kama
# Processing Record 11 of Set 7 | nishihara
# Processing Record 12 of Set 7 | banda aceh
# Processing Record 13 of Set 7 | takoradi
# Processing Record 14 of Set 7 | jumla
# Processing Record 15 of Set 7 | santa cruz
# Processing Record 16 of Set 7 | ormara
# Processing Record 17 of Set 7 | andros
# Processing Record 18 of Set 7 | salym
# Processing Record 19 of Set 7 | manaus
# Processing Record 20 of Set 7 | buala
# Processing Record 21 of Set 7 | addi ugri
# City not found. Skipping...
# Processing Record 22 of Set 7 | shurugwi
# Processing Record 23 of Set 7 | laubach
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | raton
# Processing Record 26 of Set 7 | acapulco
# Processing Record 27 of Set 7 | lakes entrance
# Processing Record 28 of Set 7 | gamba
# Processing Record 29 of Set 7 | northam
# Processing Record 30 of Set 7 | hambantota
# Processing Record 31 of Set 7 | dryden
# Processing Record 32 of Set 7 | luwingu
# Processing Record 33 of Set 7 | okakarara
# Processing Record 34 of Set 7 | hailar
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | heyang
# Processing Record 37 of Set 7 | along
# Processing Record 38 of Set 7 | cadereyta
# Processing Record 39 of Set 7 | kasane
# Processing Record 40 of Set 7 | maragogi
# Processing Record 41 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | harindanga
# Processing Record 43 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 44 of Set 7 | quelimane
# Processing Record 45 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 7 | copiapo
# Processing Record 47 of Set 7 | rio gallegos
# Processing Record 48 of Set 7 | gilbues
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 50 of Set 7 | kaitangata
# Processing Record 1 of Set 8 | xiongyue
# Processing Record 2 of Set 8 | alta floresta
# Processing Record 3 of Set 8 | auki
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | swellendam
# Processing Record 6 of Set 8 | karpogory
# Processing Record 7 of Set 8 | goya
# Processing Record 8 of Set 8 | marmande
# Processing Record 9 of Set 8 | kirakira
# Processing Record 10 of Set 8 | changli
# Processing Record 11 of Set 8 | parakou
# Processing Record 12 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 13 of Set 8 | pokhara
# Processing Record 14 of Set 8 | kokoda
# Processing Record 15 of Set 8 | emden
# Processing Record 16 of Set 8 | port-gentil
# Processing Record 17 of Set 8 | nortelandia
# Processing Record 18 of Set 8 | belaya gora
# Processing Record 19 of Set 8 | vila franca do campo
# Processing Record 20 of Set 8 | havelock
# Processing Record 21 of Set 8 | morondava
# Processing Record 22 of Set 8 | qianan
# Processing Record 23 of Set 8 | sistranda
# Processing Record 24 of Set 8 | nouadhibou
# Processing Record 25 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 8 | bijar
# Processing Record 27 of Set 8 | baruun-urt
# Processing Record 28 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 29 of Set 8 | george
# Processing Record 30 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 31 of Set 8 | bombay
# Processing Record 32 of Set 8 | srednekolymsk
# Processing Record 33 of Set 8 | izhma
# Processing Record 34 of Set 8 | hirara
# Processing Record 35 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 8 | wilmington
# Processing Record 37 of Set 8 | tuatapere
# Processing Record 38 of Set 8 | labuhan
# Processing Record 39 of Set 8 | sioux lookout
# Processing Record 40 of Set 8 | pochutla
# Processing Record 41 of Set 8 | kembe
# Processing Record 42 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 43 of Set 8 | nikolskoye
# Processing Record 44 of Set 8 | markivka
# Processing Record 45 of Set 8 | ndende
# Processing Record 46 of Set 8 | puerto madero
# Processing Record 47 of Set 8 | codrington
# Processing Record 48 of Set 8 | okrika
# Processing Record 49 of Set 8 | stephenville
# Processing Record 50 of Set 8 | camana
# Processing Record 1 of Set 9 | adrar
# Processing Record 2 of Set 9 | katha
# City not found. Skipping...
# Processing Record 3 of Set 9 | ulaanbaatar
# Processing Record 4 of Set 9 | gunnedah
# Processing Record 5 of Set 9 | ewa beach
# Processing Record 6 of Set 9 | huarmey
# Processing Record 7 of Set 9 | banswada
# Processing Record 8 of Set 9 | la ronge
# Processing Record 9 of Set 9 | nguruka
# Processing Record 10 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 9 | bengkulu
# Processing Record 12 of Set 9 | kosonsoy
# Processing Record 13 of Set 9 | acajutla
# Processing Record 14 of Set 9 | yacopi
# Processing Record 15 of Set 9 | praia da vitoria
# Processing Record 16 of Set 9 | pacific grove
# Processing Record 17 of Set 9 | san cristobal
# Processing Record 18 of Set 9 | fengzhen
# Processing Record 19 of Set 9 | lebedyan
# Processing Record 20 of Set 9 | bocana de paiwas
# Processing Record 21 of Set 9 | deputatskiy
# Processing Record 22 of Set 9 | talaya
# Processing Record 23 of Set 9 | benicarlo
# Processing Record 24 of Set 9 | kununurra
# Processing Record 25 of Set 9 | calawag
# Processing Record 26 of Set 9 | hof
# Processing Record 27 of Set 9 | verkhoyansk
# Processing Record 28 of Set 9 | alice springs
# Processing Record 29 of Set 9 | jaipur hat
# City not found. Skipping...
# Processing Record 30 of Set 9 | ushtobe
# Processing Record 31 of Set 9 | apiai
# Processing Record 32 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 9 | nipawin
# Processing Record 34 of Set 9 | waipawa
# Processing Record 35 of Set 9 | masvingo
# Processing Record 36 of Set 9 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 37 of Set 9 | takanabe
# Processing Record 38 of Set 9 | sangueya
# Processing Record 39 of Set 9 | sabzevar
# Processing Record 40 of Set 9 | broome
# Processing Record 41 of Set 9 | bilma
# Processing Record 42 of Set 9 | flinders
# Processing Record 43 of Set 9 | maniitsoq
# Processing Record 44 of Set 9 | campoverde
# Processing Record 45 of Set 9 | anzio
# Processing Record 46 of Set 9 | kavaratti
# Processing Record 47 of Set 9 | sibu
# Processing Record 48 of Set 9 | ikongo
# Processing Record 49 of Set 9 | mayumba
# Processing Record 50 of Set 9 | talnakh
# Processing Record 1 of Set 10 | jinka
# Processing Record 2 of Set 10 | vikhorevka
# Processing Record 3 of Set 10 | laramie
# Processing Record 4 of Set 10 | eforie
# City not found. Skipping...
# Processing Record 5 of Set 10 | minden
# Processing Record 6 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 7 of Set 10 | surgut
# Processing Record 8 of Set 10 | paskov
# Processing Record 9 of Set 10 | balkhash
# Processing Record 10 of Set 10 | chongwe
# Processing Record 11 of Set 10 | savannah bight
# Processing Record 12 of Set 10 | skibbereen
# Processing Record 13 of Set 10 | husavik
# Processing Record 14 of Set 10 | rocha
# Processing Record 15 of Set 10 | dalby
# Processing Record 16 of Set 10 | chunoyar
# Processing Record 17 of Set 10 | pavlovsk
# Processing Record 18 of Set 10 | la suiza
# Processing Record 19 of Set 10 | wawa
# Processing Record 20 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 21 of Set 10 | mitu
# Processing Record 22 of Set 10 | aquiraz
# Processing Record 23 of Set 10 | brejo da madre de deus
# Processing Record 24 of Set 10 | stromness
# Processing Record 25 of Set 10 | sobolevo
# Processing Record 26 of Set 10 | sankt veit
# Processing Record 27 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 28 of Set 10 | kasongo-lunda
# Processing Record 29 of Set 10 | borinskoye
# Processing Record 30 of Set 10 | ussel
# Processing Record 31 of Set 10 | iskateley
# Processing Record 32 of Set 10 | san carlos de bariloche
# Processing Record 33 of Set 10 | iquitos
# Processing Record 34 of Set 10 | ekhabi
# Processing Record 35 of Set 10 | rameswaram
# Processing Record 36 of Set 10 | san patricio
# Processing Record 37 of Set 10 | santiago del estero
# Processing Record 38 of Set 10 | shingu
# Processing Record 39 of Set 10 | bira
# Processing Record 40 of Set 10 | surman
# Processing Record 41 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 10 | atar
# Processing Record 43 of Set 10 | noumea
# Processing Record 44 of Set 10 | ancud
# Processing Record 45 of Set 10 | okha
# Processing Record 46 of Set 10 | narasannapeta
# Processing Record 47 of Set 10 | dafeng
# Processing Record 48 of Set 10 | oloron-sainte-marie
# Processing Record 49 of Set 10 | porto novo
# Processing Record 50 of Set 10 | kuching
# Processing Record 1 of Set 11 | pozo colorado
# Processing Record 2 of Set 11 | damghan
# Processing Record 3 of Set 11 | ust-omchug
# Processing Record 4 of Set 11 | lang son
# Processing Record 5 of Set 11 | riyadh
# Processing Record 6 of Set 11 | boa vista
# Processing Record 7 of Set 11 | bar harbor
# Processing Record 8 of Set 11 | kangaatsiaq
# Processing Record 9 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 11 | kamaishi
# Processing Record 11 of Set 11 | puerto leguizamo
# Processing Record 12 of Set 11 | faya
# Processing Record 13 of Set 11 | necochea
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | abha
# Processing Record 16 of Set 11 | teya
# Processing Record 17 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 18 of Set 11 | boddam
# Processing Record 19 of Set 11 | nyurba
# Processing Record 20 of Set 11 | korla
# Processing Record 21 of Set 11 | yungkang
# City not found. Skipping...
# Processing Record 22 of Set 11 | arlit
# Processing Record 23 of Set 11 | iberia
# Processing Record 24 of Set 11 | marquette
# Processing Record 25 of Set 11 | wonthaggi
# Processing Record 26 of Set 11 | tianguismanalco
# Processing Record 27 of Set 11 | gondanglegi
# Processing Record 28 of Set 11 | yazd
# Processing Record 29 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 11 | carmen
# Processing Record 31 of Set 11 | srandakan
# Processing Record 32 of Set 11 | mokhsogollokh
# Processing Record 33 of Set 11 | san andres
# Processing Record 34 of Set 11 | bikaner
# Processing Record 35 of Set 11 | guerrero negro
# Processing Record 36 of Set 11 | sumoto
# Processing Record 37 of Set 11 | apac
# Processing Record 38 of Set 11 | kopyevo
# City not found. Skipping...
# Processing Record 39 of Set 11 | santana do livramento
# Processing Record 40 of Set 11 | burica
# City not found. Skipping...
# Processing Record 41 of Set 11 | tambura
# Processing Record 42 of Set 11 | tabou
# Processing Record 43 of Set 11 | kamina
# Processing Record 44 of Set 11 | vestmanna
# Processing Record 45 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 11 | ulladulla
# Processing Record 47 of Set 11 | ostrovnoy
# Processing Record 48 of Set 11 | hamilton
# Processing Record 49 of Set 11 | shimoda
# Processing Record 50 of Set 11 | hauterive
# Processing Record 1 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 12 | zhangjiakou
# Processing Record 3 of Set 12 | olutanga
# Processing Record 4 of Set 12 | tarrafal
# Processing Record 5 of Set 12 | sestri levante
# Processing Record 6 of Set 12 | yerbogachen
# Processing Record 7 of Set 12 | xining
# Processing Record 8 of Set 12 | anshun
# Processing Record 9 of Set 12 | mogadishu
# Processing Record 10 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 12 | dunedin
# Processing Record 12 of Set 12 | loandjili
# Processing Record 13 of Set 12 | cassilandia
# Processing Record 14 of Set 12 | tura
# Processing Record 15 of Set 12 | emerald
# Processing Record 16 of Set 12 | mondlo
# Processing Record 17 of Set 12 | ternate
# Processing Record 18 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 12 | sabha
# Processing Record 20 of Set 12 | morgan city
# Processing Record 21 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 12 | shenjiamen
# Processing Record 23 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 12 | kruisfontein
# Processing Record 25 of Set 12 | laela
# Processing Record 26 of Set 12 | olga
# Processing Record 27 of Set 12 | brae
# Processing Record 28 of Set 12 | seoul
# Processing Record 29 of Set 12 | andra
# Processing Record 30 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 31 of Set 12 | bela
# Processing Record 32 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 12 | muros
# Processing Record 35 of Set 12 | saint-joseph
# Processing Record 36 of Set 12 | chara
# Processing Record 37 of Set 12 | north bend
# Processing Record 38 of Set 12 | awbari
# Processing Record 39 of Set 12 | namibe
# Processing Record 40 of Set 12 | bedford
# Processing Record 41 of Set 12 | massakory
# Processing Record 42 of Set 12 | warmbad
# Processing Record 43 of Set 12 | shahreza
# Processing Record 44 of Set 12 | lao cai
# Processing Record 45 of Set 12 | caravelas
# Processing Record 46 of Set 12 | tahta
# Processing Record 47 of Set 12 | roches noires
# City not found. Skipping...
# Processing Record 48 of Set 12 | uniontown
# Processing Record 49 of Set 12 | zhezkazgan
# Processing Record 50 of Set 12 | khandyga
# Processing Record 1 of Set 13 | fairbanks
# Processing Record 2 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 13 | ambon
# Processing Record 4 of Set 13 | chugunash
# City not found. Skipping...
# Processing Record 5 of Set 13 | chumikan
# Processing Record 6 of Set 13 | porto walter
# Processing Record 7 of Set 13 | porto santo
# Processing Record 8 of Set 13 | thinadhoo
# Processing Record 9 of Set 13 | storsteinnes
# Processing Record 10 of Set 13 | raudeberg
# Processing Record 11 of Set 13 | vagur
# Processing Record 12 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 13 | griffith
# Processing Record 14 of Set 13 | igarka
# Processing Record 15 of Set 13 | umm kaddadah
# Processing Record 16 of Set 13 | port hedland
# Processing Record 17 of Set 13 | ivanovka
# Processing Record 18 of Set 13 | quatre cocos
# Processing Record 19 of Set 13 | kudymkar
# Processing Record 20 of Set 13 | clyde river
# Processing Record 21 of Set 13 | naples
# Processing Record 22 of Set 13 | bay city
# Processing Record 23 of Set 13 | damietta
# Processing Record 24 of Set 13 | geraldton
# Processing Record 25 of Set 13 | bure
# Processing Record 26 of Set 13 | loreto
# Processing Record 27 of Set 13 | bambous virieux
# Processing Record 28 of Set 13 | havoysund
# Processing Record 29 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 13 | mashivka
# Processing Record 31 of Set 13 | finnsnes
# Processing Record 32 of Set 13 | nacala
# Processing Record 33 of Set 13 | ashland
# Processing Record 34 of Set 13 | mingaora
# Processing Record 35 of Set 13 | houlton
# Processing Record 36 of Set 13 | tsiroanomandidy
# Processing Record 37 of Set 13 | peruibe
# Processing Record 38 of Set 13 | yatou
# Processing Record 39 of Set 13 | urumqi
# Processing Record 40 of Set 13 | ballina
# Processing Record 41 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 42 of Set 13 | panjab
# Processing Record 43 of Set 13 | aksarka
# Processing Record 44 of Set 13 | ridgecrest
# Processing Record 45 of Set 13 | marang
# Processing Record 46 of Set 13 | dingle
# Processing Record 47 of Set 13 | cap-aux-meules
# Processing Record 48 of Set 13 | varena
# Processing Record 49 of Set 13 | duldurga
# Processing Record 50 of Set 13 | columbus
# Processing Record 1 of Set 14 | biryusinsk
# Processing Record 2 of Set 14 | mehamn
# Processing Record 3 of Set 14 | luganville
# Processing Record 4 of Set 14 | exeter
# Processing Record 5 of Set 14 | rexburg
# Processing Record 6 of Set 14 | isiro
# Processing Record 7 of Set 14 | henties bay
# Processing Record 8 of Set 14 | mandera
# Processing Record 9 of Set 14 | wuda
# Processing Record 10 of Set 14 | sindor
# Processing Record 11 of Set 14 | green river
# Processing Record 12 of Set 14 | gualaquiza
# Processing Record 13 of Set 14 | emilio carranza
# Processing Record 14 of Set 14 | tabas
# Processing Record 15 of Set 14 | iwanai
# Processing Record 16 of Set 14 | vitim
# Processing Record 17 of Set 14 | hinatuan
# Processing Record 18 of Set 14 | wajima
# Processing Record 19 of Set 14 | puerto del rosario
# Processing Record 20 of Set 14 | orebro
# Processing Record 21 of Set 14 | biak
# Processing Record 22 of Set 14 | hengshui
# Processing Record 23 of Set 14 | aksu
# Processing Record 24 of Set 14 | scarborough
# Processing Record 25 of Set 14 | bandarbeyla
# Processing Record 26 of Set 14 | bopfingen
# Processing Record 27 of Set 14 | rockhampton
# Processing Record 28 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 29 of Set 14 | richards bay
# Processing Record 30 of Set 14 | arona
# Processing Record 31 of Set 14 | port blair
# Processing Record 32 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 33 of Set 14 | trelew
# Processing Record 34 of Set 14 | zeya
# Processing Record 35 of Set 14 | herat
# Processing Record 36 of Set 14 | asau
# Processing Record 37 of Set 14 | amapa
# Processing Record 38 of Set 14 | samarai
# Processing Record 39 of Set 14 | kihei
# Processing Record 40 of Set 14 | campo maior
# Processing Record 41 of Set 14 | arroio grande
# Processing Record 42 of Set 14 | kalmunai
# Processing Record 43 of Set 14 | katangli
# Processing Record 44 of Set 14 | athabasca
# Processing Record 45 of Set 14 | charters towers
# Processing Record 46 of Set 14 | arroyo
# Processing Record 47 of Set 14 | mareeba
# Processing Record 48 of Set 14 | tooele
# Processing Record 49 of Set 14 | guatemalita
# City not found. Skipping...
# Processing Record 50 of Set 14 | karachi
# Processing Record 1 of Set 15 | soyo
# Processing Record 2 of Set 15 | canitas
# City not found. Skipping...
# Processing Record 3 of Set 15 | zinder
# Processing Record 4 of Set 15 | sokol
# Processing Record 5 of Set 15 | los llanos de aridane
# Processing Record 6 of Set 15 | dalvik
# Processing Record 7 of Set 15 | singaparna
# Processing Record 8 of Set 15 | yashkul
# Processing Record 9 of Set 15 | sayyan
# Processing Record 10 of Set 15 | guisa
# Processing Record 11 of Set 15 | lady frere
# Processing Record 12 of Set 15 | yarmouth
# Processing Record 13 of Set 15 | moba
# Processing Record 14 of Set 15 | urusha
# Processing Record 15 of Set 15 | vardo
# Processing Record 16 of Set 15 | coachella
# Processing Record 17 of Set 15 | boende
# Processing Record 18 of Set 15 | fare
# Processing Record 19 of Set 15 | axim
# Processing Record 20 of Set 15 | palmer
# Processing Record 21 of Set 15 | saint-louis
# Processing Record 22 of Set 15 | el tigre
# Processing Record 23 of Set 15 | acarau
# Processing Record 24 of Set 15 | hovd
# Processing Record 25 of Set 15 | wanning
# Processing Record 26 of Set 15 | tezu
# Processing Record 27 of Set 15 | jining
# Processing Record 28 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 15 | palu
# Processing Record 30 of Set 15 | saint-pierre
# Processing Record 31 of Set 15 | bandarban
# Processing Record 32 of Set 15 | matara
# Processing Record 33 of Set 15 | vostok
# Processing Record 34 of Set 15 | haines junction
# Processing Record 35 of Set 15 | kang
# Processing Record 36 of Set 15 | west wendover
# Processing Record 37 of Set 15 | sechura
# Processing Record 38 of Set 15 | agadir
# Processing Record 39 of Set 15 | sherlovaya gora
# Processing Record 40 of Set 15 | xai-xai
# Processing Record 41 of Set 15 | sept-iles
# Processing Record 42 of Set 15 | nuuk
# Processing Record 43 of Set 15 | aasiaat
# Processing Record 44 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 15 | kaseda
# Processing Record 46 of Set 15 | tigil
# Processing Record 47 of Set 15 | manggar
# Processing Record 48 of Set 15 | esso
# Processing Record 49 of Set 15 | meylan
# Processing Record 50 of Set 15 | alushta
# Processing Record 1 of Set 16 | kupang
# Processing Record 2 of Set 16 | imeni poliny osipenko
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      San Quintin  30.4833 -115.9500     74.19        64           3
# 1        Nantucket  41.2835  -70.0995     77.11        71          99
# 2     Punta Arenas -53.1500  -70.9167     35.71        93         100
# 3          Camacha  33.0833  -16.3333     65.62        83          40
# 4         Chimbote  -9.0853  -78.5783     67.78        70           3
# 5          Ushuaia -54.8000  -68.3000     31.62        86          75
# 6  Lazaro Cardenas  17.9583 -102.2000     88.88        57          26
# 7          Safford  32.8340 -109.7076     97.11        15           0
# 8              Bud  39.4470  -86.1758     76.19        97         100
# 9        Cuicatlan  17.8000  -96.9667     87.85        51          95
#
#    Wind Speed Country Current Description                 Date
# 0       15.21      MX           clear sky  2022-07-08 18:55:23
# 1       11.61      US     overcast clouds  2022-07-08 18:54:59
# 2        3.33      CL          light rain  2022-07-08 18:52:53
# 3       17.27      PT    scattered clouds  2022-07-08 18:55:24
# 4       10.20      PE           clear sky  2022-07-08 18:55:24
# 5        4.61      AR       broken clouds  2022-07-08 18:52:46
# 6        5.75      MX    scattered clouds  2022-07-08 18:53:41
# 7        2.08      US           clear sky  2022-07-08 18:55:24
# 8        3.29      US     overcast clouds  2022-07-08 18:55:25
# 9        6.44      MX     overcast clouds  2022-07-08 18:55:25

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      San Quintin      MX  30.4833 -115.9500     74.19        64           3
# 1        Nantucket      US  41.2835  -70.0995     77.11        71          99
# 2     Punta Arenas      CL -53.1500  -70.9167     35.71        93         100
# 3          Camacha      PT  33.0833  -16.3333     65.62        83          40
# 4         Chimbote      PE  -9.0853  -78.5783     67.78        70           3
# 5          Ushuaia      AR -54.8000  -68.3000     31.62        86          75
# 6  Lazaro Cardenas      MX  17.9583 -102.2000     88.88        57          26
# 7          Safford      US  32.8340 -109.7076     97.11        15           0
# 8              Bud      US  39.4470  -86.1758     76.19        97         100
# 9        Cuicatlan      MX  17.8000  -96.9667     87.85        51          95
#
#    Wind Speed Current Description
# 0       15.21           clear sky
# 1       11.61     overcast clouds
# 2        3.33          light rain
# 3       17.27    scattered clouds
# 4       10.20           clear sky
# 5        4.61       broken clouds
# 6        5.75    scattered clouds
# 7        2.08           clear sky
# 8        3.29     overcast clouds
# 9        6.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
